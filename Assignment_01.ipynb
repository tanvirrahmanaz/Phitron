# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvirrahmanaz/Phitron/blob/main/Assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number = list(map(int, input("Enter your number\n").split()))

output = filter(lambda x: x%2 == 0, number)

print(list(output))
# Out:
# Enter your number
# 5 6 7 8 9 10
# [6, 8, 10]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def safe_divide(a,b):
  try:
    return a/b
  except ZeroDivisionError:
    return "Division by zero"

number1, number2 = map(int , input("Enter Two integers a b : ").split())

result = safe_divide(number1,number2)
print(result)
# Out:
# Enter Two integers a b : 10 0
# Division by zero

# %% [markdown]
# 5
# 1![image.png](data:image/png;base64,...)

# %%
class Shape:
  def __init__(slef):
    return 0

class Rectangle(Shape):
  def __init__(self,l,w):
    self.l = l
    self.w = w
  def area(self):
    return self.l * self.w

class Circle(Shape):
  def __init__(self,r):
    self.r = r
  def area(self):
    return self.r * self.r * 3.1416

data = input().split()
shp_type = data[0]


if shp_type == "Rectangle":
  w = float(data[1])
  h = float(data[2])
  shape = Rectangle(w,h)
elif shp_type == "Circle":
  r = float(data[1])
  shape = Circle(r)
else:
  shape = Shape()


print(f"Area: {shape.area():.2f}")
# Out:
# Circle 7
# Area: 153.94

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
string = input().split()
maxval = string[0]
for i in string:
  if len(maxval)< len(i):
    maxval = i

print(maxval)
# Out:
# python programming is enjoyable
# programming

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number = int(input ())
save_number = number
def fact(num):
  for i in range(1, num):
    num *= i
  return num
sum = 0
while(number > 0):
  reminder = number%10
  number = number//10
  sum = sum + fact(reminder)

if(save_number == sum):
  print("Strong Number")
else:
  print("Not Strong Number")
# Out:
# 145
# Strong Number

# %%
142//10
# Out:
# 14
